# %%
## Import necessary modules
import requests
import time
from datetime import datetime
import pandas as pd
import numpy as np

# %% [markdown]
# ## Method - 1
# ### Offset-Limit Pagination

# %%
url = 'https://api.github.com/repositories?since=0'

base_url = 'https://api.github.com/repositories'

params = {
    "since": 100
    }

response = requests.get(base_url, params=params)

data = response.json()

print(len(data))
# Out:
# 100

# %%
data_df = pd.DataFrame(data)

data_df.head(1)
# Out:
#     id                   node_id           name               full_name  \
# 0  102  MDEwOlJlcG9zaXRvcnkxMDI=  gsa-prototype  jnewland/gsa-prototype
#
#    private                                              owner  \
# 0    False  {'login': 'jnewland', 'id': 47, 'node_id': 'MD...
#
#                                     html_url  \
# 0  https://github.com/jnewland/gsa-prototype
#
#                                          description   fork  \
# 0  Prototype/Javascript wrapper for the Google Se...  False
#
#                                                  url  ...  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...  ...
#
#                                           merges_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                          archive_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                        downloads_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                           issues_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                            pulls_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                       milestones_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                    notifications_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                           labels_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                         releases_url  \
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
#                                      deployments_url
# 0  https://api.github.com/repos/jnewland/gsa-prot...
#
# [1 rows x 46 columns]

# %% [markdown]
# ## Method: 2
# ### Page Number Pagination

# %%
url = 'https://reqres.in/api/users?page=1'

# %%
import requests

url = "https://reqres.in/api/users"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "Referer": "https://reqres.in/",
}

response = requests.get(url, params={"page": 1}, headers=headers)

print(response.status_code)
print(response.text)
# Out:
# 403
# �(� ���z��Wq�v�6C�׳A�(�	��8��9s���#d��Ո��]�ʤZ��*��!�v|-�"!Y���
# .�h�u�Vo�M��Q@!N�T���T�����8[�{޷�/�~��1����m���U����1�Gޤ�|�l�"��W~A�'���g�@���e>}L�6}���Q1��'���H���+���ҟ�c��?�������*oJ���罵���f�i���ۻ��Ծ��q��S�'%��wj����Mi��d����(����*>�m�'�n��
# Ț4z��Λ�]�����#Ĥ�};�����S��~Tq2}B6��W�o�9�'q��zܠ>��~��}�.0�m?~�����v������Q��8�G��Z`���-P�{cc1�������#�v�4`���?��O��y��z����T��?�%�{����c}�xv�+��9<���u0d�EB"$�1Dޱ%��E.�U��#��\����V3�C΅��΅3P3�c�Q��ƀ�&g����kq�ގP�e�Y�]H]�M��F�dSN��hj��JM�*��,3,$0�!Ԧ�jf%4�)9u&�ʅ��&���0�{�6�dg�����U`�V.(r7Ч����F��G!�zAB~-5CTd3�eFF�E��ٔg�)4�*�)4
# )���
# ��h�z�58����#�
# Ϊ��CMR�7��NRQ����2���P8�9?Dȉ�����ۏ�h����Y�Q���	�f��&���"Ӯz��ܞ��fq�"(��h�]$�a�C#2"#�O�S�T�d��,C����ۯ��y�
# ?v�G�k�OC[��E�Lr����J
# m@��*�)v��_l�U|b�vH�Fضe���-��y3Ǖ6
# ��9?�rٿ�o8wx��{�)�0�¬��n:}�~��}����=t�&�<����ț�{h�]�y:K����C��?Og2�0?���"$���{���RNz7W�$���p�r������v��V���.8��0t�|@@��"�¿��S��{}�x�{�ՌA�6�E��H�f��D����������y8�@��{��d�,?�������s�a������/�/�*o*��G?���m3U^���We^	��0�b���|ȷ���~(�Da5�����"
# ��~�ό�iF軖d{��2Nw�V�+����.��ٖO���׭���3�&D4��l�='�P��)�.��k䎘#f瀥"Jp��r�cx�τ+����h|�`'uyLqX�	!�C�sWe��{�V���{47�fY\�]�R	s��_��S|H��5�һ1�uٮ�5X��J�'��r���C��0�`(1�~A)Β2	�)������d#�z�r�fi�]U@��%���.EE{ކ]Y�U�A%d�U�P
# �B�0U�`]L��oL�]:� ����h-Sn|ׁY���l7�⭗�e��6:S�5����@�o�D�
# �J���	>߅�����f��f٥w�Yl]"1���5)�;P5^{ֺan���c]j�7�u���y#�#�u5����*��D��볣�:�K�/�!�ѤY��ʑܞa�D��ɀ@(/8{I/�U�rv�
# �M~��G;�w�E/��6����5�I�9\3�R�k3���^Ek"��#�0{}�����t��=��: �'!š��t�A���p!�$Q��;��.^��'�v��õ��H酺���Zu�Q���c[��MD0ß,���&()���8��J۬�B:�
# l�ݥ6�E|�P���VX�*A�Ay�)�لާ���M�k��̟bN,�6�K+8
# ]��N��;���&a!��L�#����������:���÷$���ġY_@��XN�����!���z�A��{��y,� }�Y�D#��"g�5~43)���4����%ǫ�3�{��w���x��}���@Wv��U^0#Jh�C������-)$��-Snhg/��z{���mPI1 ���� �m�����qh7���uk��f��p�6Q�;vbV=����O�����o:��S|�����BP2�S��s�^T���lus(�5�lW�M��򬒊�:���]+�<�G"��v�cPak�)ioTç�J���i)�t�ө������H˦AR_L������vD!A��ٲn�
# � Y8�H����s�O^F�4�G#?Z8qұ3��뙌D�fY{�5Ѷ�X�Դp��vGL��jn$#�'��f,���J���p������v�
# 1#��g�U�K@2~���6fp���CzkS��+�Ѥ�	�s�����*����u/&�eO�g�Ee���KHJ��f����ãd��j1%�x��|C���6@��?�~������J �� c"��p�;&w��y�Jk�j6D<.Y3d�[�С����'��`b+��uܒ�b������:�q��4�r���p�慱���=�h!`?)��C�Z�xtE��Q����r��u�������J���h�j��wF48�k��ybj{�VC��*�MB&�|�`�i_��C���-�N�5��z
# ��;�����jc��h��bv2�g�.�c� ݶo�W¨F�lds�h���&�
# �E�!k���|[(�b��y����%��^ܛ���N�4I�[��CY��P�βC7'��3+ɩ)�e!��J�%�|Vq�
# ��rs��I��d�E6���4�a=�n�"�%�Y�(�,�>�g�L?��G6��r~زE�ב�؂u�4A��a�����o�=�sWsm�,8�k�r���Ek�����UD�|�y�Utk���$"�����L�>���Ρ1B�u�����閸��y��#<K�ɨ(ͣ�챜m���=�ƌu�f��*F�S�g,�X:���	��ea�����s�M�K׸QK�b�GS��*�k�׎�Sҷ��Q�[���R�-���5�&���KG���kׁ��x��j2��7���O�����k��>Em8�q3��S�Vq7�_�1�n:���Oߧ��0j>�4�f~U�Mt�?%�P��~�?�!��q�)�f���i�s����� �p'�h�H���-��j���1;}��mgj�~������^�!N�G=�?�8�����:�s:����	����'��y\c���_�;-PF��~��5��p�X���_yr��|���8���T�溋1�S���{�S�>=�w��5~��>yF�;��N߿����O�������J� �/����k��CSNm�����Oұ���VtL��Y�G����1�4���?�)�9X��g6��/

# %%
response = requests.get(
    url,
    params={"page": 1},
    headers=headers,
    proxies={"http": None, "https": None}
)

response.status_code
# Out:
# 403

# %%
import requests
from requests.packages.urllib3.util.connection import allowed_gai_family
import socket

def force_ipv4():
    return socket.AF_INET

allowed_gai_family = force_ipv4

response = requests.get(url, headers=headers)
print(response.status_code)
# Out:
# 403

# %%
import httpx

with httpx.Client(http2=True) as client:
    response = client.get(
        "https://reqres.in/api/users",
        params={"page": 1},
        headers={
            "User-Agent": "Mozilla/5.0",
            "Accept": "application/json"
        }
    )

print(response.status_code)
print(response.json())
# Out:
# 403
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[35], line 14
#       4     response = client.get(
#       5         "https://reqres.in/api/users",
#       6         params={"page": 1},
#    (...)     10         }
#      11     )
#      13 print(response.status_code)
# ---> 14 print(response.json())
#
# File d:\personal\learn\practice\git\Data-Engineer\Python\myenv\Lib\site-packages\httpx\_models.py:832, in Response.json(self, **kwargs)
#     831 def json(self, **kwargs: typing.Any) -> typing.Any:
# --> 832     return jsonlib.loads(self.content, **kwargs)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
